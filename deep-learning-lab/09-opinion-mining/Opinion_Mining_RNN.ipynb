# %% [markdown]
# # Opinion Mining with an RNN
#
# This notebook classifies movie reviews as positive or negative. Reviews are represented as token sequences, embedded into vectors, and summarized by a recurrent neural network.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

tf.random.set_seed(42)
vocab_size, sequence_length = 10000, 200
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)
x_train = tf.keras.utils.pad_sequences(x_train[:10000], maxlen=sequence_length)
y_train = y_train[:10000]
x_test = tf.keras.utils.pad_sequences(x_test[:2000], maxlen=sequence_length)
y_test = y_test[:2000]

model = models.Sequential([
	layers.Input(shape=(sequence_length,)),
	layers.Embedding(vocab_size, 32),
	layers.SimpleRNN(32),
	layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
history = model.fit(x_train, y_train, validation_split=0.1, epochs=2, batch_size=128, verbose=1)
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")
